# %% [markdown]
# # Factor Analysis
#
# (The tool you might not be using)
#
# Everyone knows that you can use clustering to assign labels to the observations in your dataset.
#
# But what if you want to assign labels to the features? Did you know there's a tool for that? It's called factor analysis, and it's commonly used in psychology research. This notebook is a quick introduction to how it works.
#
# **The dataset**
#
# The dataset I'll be using is a fun one: *The Young People Survey* by Miroslav Sabo. It examines various personality traits as well as things that Slovakian college students like and don't like.
#
# You can find it here:
#
# https://www.kaggle.com/miroslavsabo/young-people-survey

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.decomposition import FactorAnalysis

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Load the (lightly-wrangled) data
data = pd.read_csv('responses2.csv')

# These will mess up our analysis if we keep them in the dataframe
weight = data.pop('weight')
height = data.pop('height')
age = data.pop('age')

# Remove extra column(s)
for col in data.columns:
    if 'unnamed' in col.lower():
        del data[col]

data.head()
# Out:
#    music  slow_songs_or_fast_songs  dance  folk  country  classical_music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    musical  pop  rock  metal_or_hardrock              ...               \
# 0      1.0  5.0   5.0                1.0              ...
# 1      2.0  3.0   5.0                4.0              ...
# 2      5.0  3.0   5.0                3.0              ...
# 3      1.0  2.0   2.0                1.0              ...
# 4      3.0  5.0   3.0                1.0              ...
#
#    number_of_siblings  gender  left__right_handed                education  \
# 0                 1.0  female        right handed  college/bachelor degree
# 1                 2.0  female        right handed  college/bachelor degree
# 2                 2.0  female        right handed         secondary school
# 3                 1.0  female        right handed  college/bachelor degree
# 4                 1.0  female        right handed         secondary school
#
#    only_child  village__town  house__block_of_flats  i_am_always_on_time  \
# 0          no        village         block of flats                    5
# 1          no           city         block of flats                    3
# 2          no           city         block of flats                    1
# 3         yes           city         house/bungalow                    3
# 4          no        village         house/bungalow                    5
#
#    i_lie_to_others  i_spend_a_lot_of_time_online
# 0                1                             3
# 1                3                             3
# 2                3                             3
# 3                2                             5
# 4                5                             3
#
# [5 rows x 148 columns]

# %%
# Dummify the categorical variables

for i in data.columns:
    if data[i].dtype == 'O':
        dums = pd.get_dummies(data[i], prefix=i+'_')
        del data[i]
        data = pd.concat([data, dums], axis=1)

# Now that everything is numerical, let's just use the median
# for missing values.
data.fillna(data.median(), inplace=True)

data.dtypes.value_counts()
# Out:
# float64    131
# uint8       26
# int64        8
# dtype: int64

# %% [markdown]
# # Determining the number of factors
#
# Just like with clustering, you typically don't know how many "factors" are ideal for your data. There's going to be some trial and error here.
#
# In psychology, it's widely accepted that there are 5 factors (or dimensions, if you prefer) of personality. So let's do a quick walkthrough with 5.

# %%
from sklearn.decomposition import FactorAnalysis
print('Minimum factor loadings for n factors:\n')

for n_comp in range(1,21):
    print(n_comp, end=': ')
    fa = FactorAnalysis(n_components=n_comp).fit(data)

    # Stick it in a dataframe
    factors = pd.DataFrame(fa.components_, columns=data.columns).T
    
    # Record and compare minimum factor loadings
    mins = []
    for i in factors.columns:
        factors['absol'] = abs(factors[i])
        factors_sorted = factors.sort_values('absol', ascending=False).head(4) # Top 4
        mins.append(factors_sorted['absol'].min())                             # Min value
        del factors['absol']
    
    print(np.min(np.array(mins)))
# Out:
# Minimum factor loadings for n factors:
#
# 1: 0.5602341221357283
# 2: 0.560463461131604
# 3: 0.5609574210742054
# 4: 0.45260815447720626
# 5: 0.40342127447605636
# 6: 0.294939713278729
# 7: 0.29502709319550374
# 8: 0.2748624015308651
# 9: 0.2748486391519195
# 10: 0.19773762195784178
# 11: 0.1977399387115115
# 12: 0.19238189322998026
# 13: 0.19206553949447674
# 14: 0.19251423633329182
# 15: 0.19168970185477138
# 16: 0.19200738290256628
# 17: 0.19259667730020377
# 18: 0.1927836156254579
# 19: 0.15274986149834205
# 20: 0.17110742889338112

# %%
fa = FactorAnalysis(n_components=5).fit(data)

# Stick it in a dataframe
factors = pd.DataFrame(fa.components_, columns=data.columns).T

factors
# Out:
#                                                          0         1  \
# music                                            -0.069381  0.070280
# slow_songs_or_fast_songs                          0.069407 -0.058750
# dance                                            -0.052838  0.051696
# folk                                             -0.052562  0.494050
# country                                           0.081229  0.365244
# classical_music                                  -0.001539  0.719751
# musical                                          -0.373405  0.491881
# pop                                              -0.191700 -0.019034
# rock                                              0.016471  0.283631
# metal_or_hardrock                                 0.245242  0.276230
# punk                                              0.081073  0.245490
# hiphop_rap                                        0.144789 -0.067879
# reggae_ska                                        0.010942  0.293433
# swing_jazz                                       -0.053908  0.630821
# rock_n_roll                                      -0.010033  0.508355
# alternative                                      -0.000364  0.428399
# latino                                           -0.383317  0.439546
# techno_trance                                     0.220200  0.025942
# opera                                            -0.048004  0.648563
# movies                                           -0.019116  0.047357
# horror                                            0.230583 -0.124591
# thriller                                          0.228315  0.018810
# comedy                                           -0.019877 -0.015215
# romantic                                         -0.541651  0.137070
# scifi                                             0.410548  0.188868
# war                                               0.561039  0.238949
# fantasy/fairy_tales                              -0.354874  0.264542
# animated                                         -0.233091  0.209765
# documentary                                       0.136598  0.443421
# western                                           0.414187  0.323421
# ...                                                    ...       ...
# number_of_siblings                                0.033732  0.109612
# i_am_always_on_time                               0.147420  0.055658
# i_lie_to_others                                  -0.000924 -0.117028
# i_spend_a_lot_of_time_online                      0.094861 -0.104485
# smoking__current smoker                           0.002762 -0.043016
# smoking__former smoker                           -0.012075 -0.010512
# smoking__never smoked                            -0.002417  0.036527
# smoking__tried smoking                            0.010216  0.019076
# alcohol__drink a lot                              0.056140 -0.029265
# alcohol__never                                    0.009021  0.012055
# alcohol__social drinker                          -0.065100  0.017911
# punctuality_categorical__i am always on time      0.032447  0.020937
# punctuality_categorical__i am often early         0.008467 -0.012742
# punctuality_categorical__i am often running late -0.041263 -0.006892
# gender__female                                   -0.488717 -0.001906
# gender__male                                      0.487864  0.003681
# left__right_handed__left handed                   0.024440  0.005385
# left__right_handed__right handed                 -0.024045 -0.005568
# education__college/bachelor degree                0.004762  0.028459
# education__currently a primary school pupil      -0.000221  0.002873
# education__doctorate degree                       0.005821  0.003619
# education__masters degree                         0.006131  0.031106
# education__primary school                        -0.015237 -0.039411
# education__secondary school                      -0.000453 -0.027965
# only_child__no                                    0.008932  0.020867
# only_child__yes                                  -0.009330 -0.020415
# village__town__city                              -0.001229 -0.049822
# village__town__village                            0.000507  0.050172
# house__block_of_flats__block of flats             0.000609 -0.044733
# house__block_of_flats__house/bungalow             0.000741  0.047806
#
#                                                          2         3         4
# music                                            -0.078323  0.040963  0.081981
# slow_songs_or_fast_songs                         -0.150641  0.073819 -0.046562
# dance                                            -0.477774 -0.184094 -0.058575
# folk                                              0.144885 -0.139008 -0.032167
# country                                           0.115704 -0.045446  0.002401
# classical_music                                   0.340046  0.012277  0.260682
# musical                                           0.017753 -0.108138  0.115664
# pop                                              -0.375983 -0.263318  0.022136
# rock                                              0.300872  0.300420  0.268782
# metal_or_hardrock                                 0.425969  0.395199  0.177400
# punk                                              0.262068  0.287035  0.232898
# hiphop_rap                                       -0.638089 -0.065359  0.007808
# reggae_ska                                       -0.089321  0.201598  0.121655
# swing_jazz                                        0.161414  0.160025  0.249006
# rock_n_roll                                       0.193880  0.227212  0.253861
# alternative                                       0.345764  0.329623  0.354118
# latino                                           -0.205815 -0.146425 -0.082043
# techno_trance                                    -0.353620 -0.112427  0.015752
# opera                                             0.213378 -0.000767  0.143176
# movies                                           -0.126408  0.030606  0.106958
# horror                                           -0.221422  0.210283  0.177589
# thriller                                         -0.083466  0.123772  0.165410
# comedy                                           -0.212590 -0.103808 -0.034467
# romantic                                         -0.253564 -0.327578  0.027428
# scifi                                             0.098582  0.098697  0.136784
# war                                              -0.048867  0.161513  0.102048
# fantasy/fairy_tales                              -0.077198 -0.157597  0.066493
# animated                                         -0.010461 -0.040221  0.107731
# documentary                                       0.190276 -0.002288 -0.008252
# western                                           0.031761  0.086632  0.005308
# ...                                                    ...       ...       ...
# number_of_siblings                                0.020164 -0.017318 -0.069924
# i_am_always_on_time                              -0.059057 -0.152574 -0.416822
# i_lie_to_others                                   0.014967  0.139986  0.228809
# i_spend_a_lot_of_time_online                      0.016474  0.055977  0.198064
# smoking__current smoker                          -0.047920  0.074464  0.060019
# smoking__former smoker                           -0.016912  0.036856  0.024978
# smoking__never smoked                             0.072282 -0.074422 -0.076251
# smoking__tried smoking                           -0.008448 -0.039809 -0.009490
# alcohol__drink a lot                             -0.025660  0.141223  0.105352
# alcohol__never                                    0.011339 -0.047485 -0.040311
# alcohol__social drinker                           0.016719 -0.096087 -0.066605
# punctuality_categorical__i am always on time     -0.039112  0.003920 -0.089033
# punctuality_categorical__i am often early         0.050632 -0.083570 -0.029678
# punctuality_categorical__i am often running late -0.009584  0.080207  0.119377
# gender__female                                   -0.000240  0.014229 -0.005858
# gender__male                                     -0.001690 -0.009758  0.002068
# left__right_handed__left handed                   0.000931 -0.022316 -0.002732
# left__right_handed__right handed                 -0.002285  0.021366  0.003004
# education__college/bachelor degree               -0.018037  0.025622 -0.000261
# education__currently a primary school pupil      -0.004043 -0.004606  0.002248
# education__doctorate degree                       0.000419 -0.002895  0.003444
# education__masters degree                         0.017080 -0.026143 -0.014843
# education__primary school                         0.006255  0.008512  0.024710
# education__secondary school                      -0.000698 -0.000369 -0.015294
# only_child__no                                    0.016540 -0.024903 -0.031429
# only_child__yes                                  -0.016682  0.023786  0.029775
# village__town__city                              -0.012957  0.106754  0.074251
# village__town__village                            0.013220 -0.104985 -0.073660
# house__block_of_flats__block of flats            -0.006555  0.100358  0.067167
# house__block_of_flats__house/bungalow             0.005862 -0.099376 -0.064617
#
# [165 rows x 5 columns]

# %%
def show_loadings(factor=0, factors=factors):
    loadings = pd.DataFrame()
    loadings['loading'] = factors[factor]
    loadings['absol_' + str(factor)] = abs(loadings['loading'])
    loadings = loadings[loadings['absol_' + str(factor)] > 0.4]\
    .sort_values('absol_' + str(factor), ascending=False)
    return pd.DataFrame(loadings['loading'])

show_loadings(0)
# Out:
#                                                      loading
# i_cry_when_i_feel_down_or_things_dont_go_the_ri... -0.791775
# cars                                                0.636347
# pc                                                  0.614638
# war                                                 0.561039
# reading                                            -0.551145
# romantic                                           -0.541651
# phobia_spiders                                     -0.523123
# action                                              0.510810
# shopping                                           -0.508355
# gender__female                                     -0.488717
# gender__male                                        0.487864
# science_and_technology                              0.463925
# dancing                                            -0.463136
# theatre                                            -0.449713
# phobia_darkness                                    -0.415532
# western                                             0.414187
# scifi                                               0.410548

# %%
show_loadings(1)
# Out:
#                                               loading
# classical_music                              0.719751
# opera                                        0.648563
# art_exhibitions                              0.648239
# musical_instruments                          0.635492
# swing_jazz                                   0.630821
# theatre                                      0.607410
# reading                                      0.588138
# religion                                     0.552343
# history                                      0.523211
# medicine                                     0.515634
# rock_n_roll                                  0.508355
# i_often_study_or_work_even_in_my_spare_time  0.499805
# folk                                         0.494050
# musical                                      0.491881
# biology                                      0.455167
# documentary                                  0.443421
# latino                                       0.439546
# psychology                                   0.438908
# dancing                                      0.428935
# alternative                                  0.428399
# i_always_try_to_vote_in_elections            0.427357
# countryside_outdoors                         0.426700
# writing                                      0.423684
# geography                                    0.423601
# science_and_technology                       0.419804
# i_have_many_different_hobbies_and_interests  0.408484

# %%
show_loadings(2)
# Out:
#                                                      loading
# i_spend_a_lot_of_money_on_my_appearance            -0.710439
# i_enjoy_going_to_large_shopping_centres            -0.679245
# shopping                                           -0.678412
# hiphop_rap                                         -0.638089
# i_prefer_branded_clothing_to_non_branded           -0.572782
# i_have_lots_of_friends                             -0.507483
# adrenaline_sports                                  -0.499998
# active_sport                                       -0.498390
# i_am_always_full_of_life_and_energy                -0.490674
# dance                                              -0.477774
# cars                                               -0.475849
# celebrities                                        -0.473508
# i_spend_a_lot_of_money_on_gadgets                  -0.448779
# i_spend_a_lot_of_money_on_partying_and_socializing -0.446421
# i_always_make_sure_i_connect_with_the_right_people -0.443008
# i_enjoy_meeting_new_people                         -0.430717
# metal_or_hardrock                                   0.425969
# dancing                                            -0.424140

# %%
show_loadings(3)
# Out:
#                                                      loading
# phobia_dangerous_dogs                              -0.553878
# phobia_snakes                                      -0.533101
# phobia_rats                                        -0.469641
# i_have_to_be_well_prepared_before_public_speaking  -0.436367
# i_worry_about_my_health                            -0.426880
# i_prefer_big_dangerous_dogs_to_smaller_calmer_dogs  0.422508

# %%
show_loadings(4)
# Out:
#                                                      loading
# i_wish_i_could_change_the_past_because_of_the_t...  0.440735
# i_am_always_on_time                                -0.416822
# i_feel_lonely_in_life                               0.414363
# phobia_aging                                        0.403421
